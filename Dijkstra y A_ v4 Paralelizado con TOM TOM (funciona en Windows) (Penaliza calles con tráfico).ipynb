# %%
# YA FUNCIONA EN WINDOWS

# %%
#!pip install osmnx folium geopy pandas --upgrade

# %%
# Importar las librerías necesarias
import osmnx as ox
import networkx as nx
import folium
import pandas as pd
import heapq
from geopy.distance import geodesic
import time
import math
import os
import pickle
from concurrent.futures import ProcessPoolExecutor, ThreadPoolExecutor

import requests  #  llamar a la API de TomTom

# %%
# ===================== FUNCIONES TOMTOM =====================
import os
import requests
import folium

TOMTOM_API_KEY = os.getenv("TOMTOM_API_KEY")

if not TOMTOM_API_KEY:
    raise ValueError("ERROR: La variable de entorno TOMTOM_API_KEY no está configurada.")

# -------- Routing (ya lo tenías) --------
def tomtom_route_eta(lat_o, lon_o, lat_d, lon_d):
    """
    Llama a la Routing API de TomTom y devuelve:
      - distance_m: distancia total en metros
      - travel_s: tiempo total de viaje (segundos, con condiciones actuales)
      - delay_s: retraso por tráfico (segundos, si TomTom lo reporta)
    """
    url = f"https://api.tomtom.com/routing/1/calculateRoute/{lat_o},{lon_o}:{lat_d},{lon_d}/json"

    params = {
        "key": TOMTOM_API_KEY,
        "routeType": "fastest",
        "traffic": "true",   # considerar tráfico
        "departAt": "now"    # condiciones actuales
    }

    resp = requests.get(url, params=params)
    resp.raise_for_status()
    data = resp.json()

    summary = data["routes"][0]["summary"]

    distance_m = summary.get("lengthInMeters")
    travel_s   = summary.get("travelTimeInSeconds")
    delay_s    = summary.get("trafficDelayInSeconds", 0)

    return distance_m, travel_s, delay_s


def tomtom_from_graph_nodes(G, start_node, end_node):
    """
    Wrapper que toma nodos del grafo OSMnx y llama a tomtom_route_eta.
    """
    lat_o, lon_o = G.nodes[start_node]["y"], G.nodes[start_node]["x"]
    lat_d, lon_d = G.nodes[end_node]["y"], G.nodes[end_node]["x"]

    return tomtom_route_eta(lat_o, lon_o, lat_d, lon_d)


# -------- Traffic Flow (NUEVO: para colorear tráfico) --------
def tomtom_flow_segment(lat, lon, zoom=10):
    """
    Llama a la Traffic Flow 'Flow Segment Data' API de TomTom, estilo 'absolute'.
    Devuelve el objeto flowSegmentData completo.
    Docs:
    https://developer.tomtom.com/traffic-api/documentation/tomtom-maps/traffic-flow/flow-segment-data
    """
    url = f"https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/{zoom}/json"
    params = {
        "key": TOMTOM_API_KEY,
        "point": f"{lat},{lon}",
    }
    resp = requests.get(url, params=params)
    resp.raise_for_status()
    data = resp.json()
    return data["flowSegmentData"]


def traffic_color_from_ratio(ratio, road_closure=False):
    """
    Convierte el ratio currentSpeed/freeFlowSpeed en un color tipo tráfico.
    """
    if road_closure:
        return "black"
    if ratio is None:
        return "gray"
    if ratio >= 0.9:
        return "green"
    elif ratio >= 0.7:
        return "yellow"
    elif ratio >= 0.4:
        return "orange"
    else:
        return "red"


def build_traffic_map_from_segments(segments, center_lat, center_lon, save_path=None):
    """
    Construye un mapa Folium con segmentos coloreados según el tráfico.
    segments: lista de dicts con claves:
      - 'coords': lista [(lat, lon), ...]
      - 'color': string ('green', 'yellow', 'orange', 'red', 'black', 'gray')
    """
    m = folium.Map(location=[center_lat, center_lon], zoom_start=14)

    for seg in segments:
        coords = seg.get("coords", [])
        color = seg.get("color", "blue")
        if coords:
            folium.PolyLine(coords, color=color, weight=6).add_to(m)

    if save_path:
        os.makedirs(os.path.dirname(save_path), exist_ok=True)
        m.save(save_path)

    return m

# ============================================================

# %%
def clean_graph(G, network_type):
    max_speed = {'drive': 40, 'walk': 5}
    for u, v, k in G.edges(keys=True):
        length = G.edges[u, v, k]["length"]
        max_speed_value = max_speed[network_type]

        # Penalización por tipo de calle
        penalty = 1.5 if "highway" in G.edges[u, v, k] and G.edges[u, v, k]["highway"] in ["residential", "tertiary"] else 1.0

        G.edges[u, v, k]["maxspeed"] = max_speed_value
        G.edges[u, v, k]["weight"] = (length / max_speed_value) * penalty
    return G

# %%
# Función para inicializar estilos de aristas
def initialize_edge_styles(G):
    for edge in G.edges:
        G.edges[edge]["color"] = "#d36206"
        G.edges[edge]["alpha"] = 0.2
        G.edges[edge]["linewidth"] = 0.5

# %%
# Solicitar las coordenadas de inicio y destino
def get_coordinates():
    while True:
        try:
            coords = input("Ingrese las coordenadas (latitud, longitud): ").strip()
            lat, lon = map(float, coords.split(","))
            return (lat, lon)
        except ValueError:
            print("Entrada inválida. Por favor, ingrese las coordenadas en el formato 'lat,lon'.")

# %%
# Solicitar el tipo de transporte
def get_transport_type():
    while True:
        print("Ingrese el tipo de viaje que realizará:")
        print("  1. Auto")
        print("  2. Caminando")
        try:
            option = int(input("Seleccione una opción (1 o 2): ").strip())
            if option in [1, 2]:
                return 'drive' if option == 1 else 'walk'
            else:
                print("Opción inválida. Por favor seleccione 1 o 2.")
        except ValueError:
            print("Entrada inválida. Por favor ingrese un número (1 o 2).")

# %%
# Algoritmo de Dijkstra
def dijkstra(G, orig, dest):
    for node in G.nodes:
        G.nodes[node]["visited"] = False
        G.nodes[node]["distance"] = float("inf")
        G.nodes[node]["previous"] = None
    G.nodes[orig]["distance"] = 0
    pq = [(0, orig)]
    while pq:
        _, node = heapq.heappop(pq)
        if node == dest:
            break
        if G.nodes[node]["visited"]:
            continue
        G.nodes[node]["visited"] = True
        for u, v, k in G.out_edges(node, keys=True):
            weight = G.edges[u, v, k]["weight"]
            if G.nodes[v]["distance"] > G.nodes[node]["distance"] + weight:
                G.nodes[v]["distance"] = G.nodes[node]["distance"] + weight
                G.nodes[v]["previous"] = node
                heapq.heappush(pq, (G.nodes[v]["distance"], v))

# %%
# Algoritmo A*
def a_star(G, orig, dest):
    def heuristic(node1, node2):
        x1, y1 = G.nodes[node1]["x"], G.nodes[node1]["y"]
        x2, y2 = G.nodes[node2]["x"], G.nodes[node2]["y"]
        return geodesic((y1, x1), (y2, x2)).meters  # Distancia geodésica en metros

    for node in G.nodes:
        G.nodes[node]["g_score"] = float("inf")
        G.nodes[node]["f_score"] = float("inf")
        G.nodes[node]["previous"] = None

    G.nodes[orig]["g_score"] = 0
    G.nodes[orig]["f_score"] = heuristic(orig, dest)
    pq = [(G.nodes[orig]["f_score"], orig)]

    while pq:
        _, node = heapq.heappop(pq)
        if node == dest:
            break
        for u, v, k in G.out_edges(node, keys=True):
            tentative_g_score = G.nodes[node]["g_score"] + G.edges[u, v, k]["weight"]
            if tentative_g_score < G.nodes[v]["g_score"]:
                G.nodes[v]["g_score"] = tentative_g_score
                G.nodes[v]["f_score"] = tentative_g_score + heuristic(v, dest)
                G.nodes[v]["previous"] = node
                heapq.heappush(pq, (G.nodes[v]["f_score"], v))

# %%
def get_path_edges_from_previous(G, start_node, end_node):
    path_nodes = []
    curr = end_node
    while curr != start_node:
        prev = G.nodes[curr].get("previous", None)
        if prev is None:
            return None
        path_nodes.append((prev, curr))
        curr = prev
    path_nodes.reverse()
    return path_nodes


def get_path_edges_networkx(G, start_node, end_node):
    real_nodes = nx.shortest_path(G, start_node, end_node, weight="weight")
    real_edges = []
    for u, v in zip(real_nodes[:-1], real_nodes[1:]):
        real_edges.append((u, v))
    return real_edges


def compare_paths(pred_edges, real_edges):
    if pred_edges is None or real_edges is None:
        return {
            "tp": 0, "fp": 0, "fn": 0,
            "precision": 0.0, "recall": 0.0, "f1": 0.0
        }

    # Normalizamos los arcos para no depender de la dirección en la comparación
    norm_pred = {tuple(sorted(e)) for e in pred_edges}
    norm_real = {tuple(sorted(e)) for e in real_edges}

    tp = len(norm_pred & norm_real)
    fp = len(norm_pred - norm_real)
    fn = len(norm_real - norm_pred)

    precision = tp / (tp + fp) if (tp + fp) > 0 else 0.0
    recall    = tp / (tp + fn) if (tp + fn) > 0 else 0.0
    f1        = (2 * precision * recall / (precision + recall)) if (precision + recall) > 0 else 0.0

    return {"tp": tp, "fp": fp, "fn": fn,
            "precision": precision, "recall": recall, "f1": f1}


def evaluate_pair(G, start_node, end_node, network_type="drive"):
    """
    Evalúa un par (origen, destino) en el grafo:
      - Dijkstra base (sin tráfico)
      - A* base (sin tráfico)
      - Penaliza pesos según tráfico en la ruta A* base (TomTom Traffic Flow)
      - Dijkstra con tráfico (pesos penalizados)
      - A* con tráfico (pesos penalizados)
      - Métricas de tiempo, distancia, precisión/recall para todas las variantes
      - TomTom Routing para ETA global
      - TomTom Traffic Flow sobre la ruta final A* con tráfico para colorear el mapa
    """
    results = {}

    # ===================== 1) DIJKSTRA BASE (sin tráfico) =====================
    t0 = time.perf_counter()
    dijkstra(G, start_node, end_node)
    t1 = time.perf_counter()
    dijkstra_time_base = (t1 - t0) * 1000  # ms

    dijkstra_edges_base = get_path_edges_from_previous(G, start_node, end_node)
    if dijkstra_edges_base:
        dijkstra_dist_base = sum(G.edges[u, v, 0]["length"] for (u, v) in dijkstra_edges_base)
    else:
        dijkstra_dist_base = math.inf

    # ===================== 2) A* BASE (sin tráfico) =====================
    t0 = time.perf_counter()
    a_star(G, start_node, end_node)
    t1 = time.perf_counter()
    astar_time_base = (t1 - t0) * 1000  # ms

    astar_edges_base = get_path_edges_from_previous(G, start_node, end_node)
    if astar_edges_base:
        astar_dist_base = sum(G.edges[u, v, 0]["length"] for (u, v) in astar_edges_base)
    else:
        astar_dist_base = math.inf

    # ===================== 3) Ruta "real" de referencia (networkx) =====================
    real_edges = get_path_edges_networkx(G, start_node, end_node)

    d_base_metrics   = compare_paths(dijkstra_edges_base, real_edges)
    a_base_metrics   = compare_paths(astar_edges_base, real_edges)

    # ===================== 4) Penalizar pesos según tráfico en ruta A* base =====================
    max_factor = 3.0  # tope de penalización (por ejemplo, máximo 3x el peso original)

    if astar_edges_base:
        for (u, v) in astar_edges_base:
            try:
                lat_u, lon_u = G.nodes[u]["y"], G.nodes[u]["x"]
                flow = tomtom_flow_segment(lat_u, lon_u, zoom=10)

                curr = flow.get("currentSpeed")
                free = flow.get("freeFlowSpeed")

                if curr and free and curr > 0:
                    ratio = curr / free  # < 1 si hay tráfico
                    if ratio < 1.0:
                        factor = min(1.0 / ratio, max_factor)  # ≈ free/curr
                    else:
                        factor = 1.0
                else:
                    factor = 1.0  # si no hay info, no modificamos

                # Ajustamos el peso de TODAS las keys de la arista (MultiDiGraph)
                for k in G[u][v]:
                    if "weight" in G[u][v][k]:
                        G[u][v][k]["weight"] *= factor

            except Exception as e:
                print(f"[WARN] No se pudo ajustar tráfico en {u}->{v}: {e}")
                continue

    # ===================== 5) DIJKSTRA CON TRÁFICO (pesos penalizados) =====================
    t0 = time.perf_counter()
    dijkstra(G, start_node, end_node)
    t1 = time.perf_counter()
    dijkstra_time_traffic = (t1 - t0) * 1000  # ms

    dijkstra_edges_traffic = get_path_edges_from_previous(G, start_node, end_node)
    if dijkstra_edges_traffic:
        dijkstra_dist_traffic = sum(G.edges[u, v, 0]["length"] for (u, v) in dijkstra_edges_traffic)
    else:
        dijkstra_dist_traffic = math.inf

    d_traffic_metrics = compare_paths(dijkstra_edges_traffic, real_edges)

    # ===================== 6) A* CON TRÁFICO (pesos penalizados) =====================
    t0 = time.perf_counter()
    a_star(G, start_node, end_node)
    t1 = time.perf_counter()
    astar_time_traffic = (t1 - t0) * 1000  # ms

    astar_edges_traffic = get_path_edges_from_previous(G, start_node, end_node)
    if astar_edges_traffic:
        astar_dist_traffic = sum(G.edges[u, v, 0]["length"] for (u, v) in astar_edges_traffic)
    else:
        astar_dist_traffic = math.inf

    a_traffic_metrics = compare_paths(astar_edges_traffic, real_edges)

    # ===================== 7) Speedups y eficiencia =====================
    speedup_A_base      = dijkstra_time_base    / astar_time_base    if astar_time_base    > 0 else 0.0
    eficiencia_A_base   = speedup_A_base / 1.0

    speedup_A_traffic   = dijkstra_time_base    / astar_time_traffic if astar_time_traffic > 0 else 0.0
    eficiencia_A_traf   = speedup_A_traffic / 1.0

    speedup_D_traffic   = dijkstra_time_base    / dijkstra_time_traffic if dijkstra_time_traffic > 0 else 0.0
    eficiencia_D_traf   = speedup_D_traffic / 1.0

    # ===================== 8) TomTom ROUTING (ETA global tramo start->end) =====================
    try:
        tt_dist_m, tt_time_s, tt_delay_s = tomtom_from_graph_nodes(G, start_node, end_node)
    except Exception as e:
        print(f"[WARN] Error al llamar a TomTom Routing para {start_node} -> {end_node}: {e}")
        tt_dist_m, tt_time_s, tt_delay_s = None, None, None

    # ===================== 9) TomTom TRAFFIC FLOW sobre la ruta FINAL A* (con tráfico) =====================
    traffic_segments = []
    ratios = []

    if astar_edges_traffic:
        for (u, v) in astar_edges_traffic:
            try:
                lat_u, lon_u = G.nodes[u]["y"], G.nodes[u]["x"]
                flow = tomtom_flow_segment(lat_u, lon_u, zoom=10)

                curr = flow.get("currentSpeed")
                free = flow.get("freeFlowSpeed")
                road_closure = flow.get("roadClosure", False)
                coords_raw = flow.get("coordinates", {}).get("coordinate", [])

                if free and free > 0:
                    ratio = curr / free
                else:
                    ratio = None

                color = traffic_color_from_ratio(ratio, road_closure)
                coords = [(c["latitude"], c["longitude"]) for c in coords_raw]

                traffic_segments.append({
                    "coords": coords,
                    "currentSpeed": curr,
                    "freeFlowSpeed": free,
                    "ratio": ratio,
                    "roadClosure": road_closure,
                    "color": color,
                })

                if ratio is not None:
                    ratios.append(ratio)

            except Exception as e:
                print(f"[WARN] Error en Traffic Flow para arista {u}->{v}: {e}")
                continue

    if ratios:
        avg_ratio = sum(ratios) / len(ratios)
        congested_fraction = sum(1 for r in ratios if r < 0.7) / len(ratios)
    else:
        avg_ratio = None
        congested_fraction = None

    # ===================== 10) Guardar todo en results =====================

    # Dijkstra base
    results["dijkstra_time_ms"] = dijkstra_time_base
    results["dijkstra_dist_m"] = dijkstra_dist_base
    results["dijkstra_precision"] = d_base_metrics["precision"]
    results["dijkstra_recall"] = d_base_metrics["recall"]
    results["dijkstra_f1"] = d_base_metrics["f1"]

    # Dijkstra con tráfico
    results["dijkstra_traffic_time_ms"] = dijkstra_time_traffic
    results["dijkstra_traffic_dist_m"] = dijkstra_dist_traffic
    results["dijkstra_traffic_precision"] = d_traffic_metrics["precision"]
    results["dijkstra_traffic_recall"] = d_traffic_metrics["recall"]
    results["dijkstra_traffic_f1"] = d_traffic_metrics["f1"]
    results["speedup_Dijkstra_traffic_vs_base"] = speedup_D_traffic
    results["eficiencia_Dijkstra_traffic"] = eficiencia_D_traf

    # A* base
    results["astar_time_ms"] = astar_time_base
    results["astar_dist_m"] = astar_dist_base
    results["astar_precision"] = a_base_metrics["precision"]
    results["astar_recall"] = a_base_metrics["recall"]
    results["astar_f1"] = a_base_metrics["f1"]
    results["speedup_A*_vs_Dijkstra"] = speedup_A_base
    results["eficiencia_A*_base"] = eficiencia_A_base

    # A* con tráfico
    results["astar_traffic_time_ms"] = astar_time_traffic
    results["astar_traffic_dist_m"] = astar_dist_traffic
    results["astar_traffic_precision"] = a_traffic_metrics["precision"]
    results["astar_traffic_recall"] = a_traffic_metrics["recall"]
    results["astar_traffic_f1"] = a_traffic_metrics["f1"]
    results["speedup_A*_traffic_vs_Dijkstra_base"] = speedup_A_traffic
    results["eficiencia_A*_traffic"] = eficiencia_A_traf

    # TomTom Routing
    results["tomtom_dist_m"] = tt_dist_m
    results["tomtom_time_s"] = tt_time_s
    results["tomtom_delay_s"] = tt_delay_s

    # Métricas de Traffic Flow (ruta A* final)
    results["traffic_avg_speed_ratio"] = avg_ratio
    results["traffic_congested_fraction"] = congested_fraction
    results["traffic_segments"] = traffic_segments

    
    results["eficiencia"] = results["eficiencia_A*_base"]

    
    return results




def eval_task(args):
    """
    Tarea que se puede correr en paralelo.
    Se hace una copia del grafo para no pisar los 'previous' de otros hilos.
    """
    G, start_node, end_node, start_name, end_name, network_type = args
    G_local = G.copy()  # <- cada proceso/hilo trabaja con su copia

    r = evaluate_pair(G_local, start_node, end_node, network_type=network_type)
    r["origen"] = start_name
    r["destino"] = end_name
    return r


from concurrent.futures import ProcessPoolExecutor

def evaluate_pairs_parallel(G, nodes, point_names, network_type="drive", max_workers=4):
    """
    Versión paralela basada en ProcessPoolExecutor (esta puede ser
    sobrescrita en la celda 17 con la versión que usa ThreadPool en Windows).
    """
    tasks = []
    for i in range(len(point_names) - 1):
        start_name = point_names[i]
        end_name = point_names[i + 1]
        start_node = nodes[start_name]
        end_node = nodes[end_name]
        tasks.append((G, start_node, end_node, start_name, end_name, network_type))

    results = []
    with ProcessPoolExecutor(max_workers=max_workers) as ex:
        for r in ex.map(eval_task, tasks):
            results.append(r)

    return results

# %%
# Mostrar resultados en tabla
def show_results_in_table(total_time, total_distance):
    """
    Muestra los resultados finales en una tabla.
    """
    data = {
        "Algoritmo": ["Dijkstra", "A*"],
        "Distancia Total (km)": [
            total_distance["Dijkstra"] / 1000,  # Convertir de metros a kilómetros
            total_distance["A*"] / 1000
        ],
        "Tiempo Total (minutos)": [
            total_time["Dijkstra"],
            total_time["A*"]
        ]
    }

    # Crear el DataFrame y mostrarlo
    df_results = pd.DataFrame(data)
    display(df_results)

# %%
# Obtener las coordenadas de la ruta más corta
def get_route_coordinates(G, orig, dest):
    path = []
    curr = dest
    while curr != orig:
        prev = G.nodes[curr]["previous"]
        if prev is None:
            print("No se pudo encontrar un camino desde el origen al destino.")
            return None
        path.append((G.nodes[curr]["y"], G.nodes[curr]["x"]))
        curr = prev
    path.append((G.nodes[orig]["y"], G.nodes[orig]["x"]))
    path.reverse()
    return path

# %%
# Visualizar la ruta con Folium
def plot_route_with_folium(G, orig, dest, route_coordinates):
    folium_map = folium.Map(
        location=[G.nodes[orig]['y'], G.nodes[orig]['x']],
        zoom_start=14,
        tiles='OpenStreetMap'
    )
    folium.Marker(
        location=[G.nodes[orig]['y'], G.nodes[orig]['x']],
        popup="Inicio",
        icon=folium.Icon(color="green", icon="play"),
    ).add_to(folium_map)
    folium.Marker(
        location=[G.nodes[dest]['y'], G.nodes[dest]['x']],
        popup="Destino",
        icon=folium.Icon(color="red", icon="stop"),
    ).add_to(folium_map)
    folium.PolyLine(
        route_coordinates,
        color="blue",
        weight=5,
        opacity=0.8,
        tooltip="Ruta más corta"
    ).add_to(folium_map)
    return folium_map

# %%
# Coordenadas guardadas
saved_coordinates = {
    "UPIIT": (19.323118, -98.233548),
    "Parque de Zacatelco": (19.215691, -98.240524),
    "Soriana Ocotlan": (19.318605, -98.220713),
    "Zoologico del Altiplano": (19.338439, -98.199046),
    "Recinto Ferial": (19.32500854887219, -98.24458295157108),
    "Escalinatas": (19.3163317057408, -98.2432146346621),
    "Jardín botánico": (19.328860233644402, -98.2186988643214),
    "Museo Nacional del Títere": (19.31306644075224, -97.92325948735258),
    "Museo Taurino de Huamantla": (19.315214643452563, -97.92088832789638),
    "Parque de Apizaco": (19.41583668098076, -98.1404040514315),
    "Parque de Tlaxco": (19.614479362946597, -98.11878748334519),
    "Centro Turístico Zacatelco": (19.201482353314457, -98.250818177072),
    "Val'Quirico": (19.19134212101139, -98.28932538116192),
    "Cacaxtla": (19.244591586170426, -98.33845364678213),
}

# Función para obtener coordenadas (seleccionar de lista o ingresar manualmente)
def get_coordinates_with_saved_options():
    print("\n¿Desea seleccionar un punto de la lista predefinida o ingresar coordenadas manualmente?")
    print("  1. Seleccionar de la lista")
    print("  2. Ingresar manualmente")
    while True:
        try:
            option = int(input("Seleccione una opción (1 o 2): ").strip())
            if option == 1:
                print("\nPuntos disponibles:")
                for idx, (name, coord) in enumerate(saved_coordinates.items(), start=1):
                    print(f"  {idx}. {name} - Coordenadas: {coord}")
                while True:
                    try:
                        choice = int(input("Seleccione un punto por su número: ").strip())
                        if 1 <= choice <= len(saved_coordinates):
                            selected_name = list(saved_coordinates.keys())[choice - 1]
                            print(f"Ha seleccionado: {selected_name} - Coordenadas: {saved_coordinates[selected_name]}")
                            return saved_coordinates[selected_name]
                        else:
                            print("Por favor, seleccione un número válido de la lista.")
                    except ValueError:
                        print("Entrada inválida. Por favor, ingrese un número.")
            elif option == 2:
                return get_coordinates()  # Llama a la función manual existente
            else:
                print("Por favor, seleccione una opción válida (1 o 2).")
        except ValueError:
            print("Entrada inválida. Por favor, ingrese un número.")

# %%
# Función para agregar puntos dinámicamente
def get_multiple_points():
    points = {}  # Diccionario para almacenar los puntos con sus nombres
    point_counter = 0  # Contador para nombrar los puntos dinámicamente (A, B, C, etc.)

    while True:
        # Generar el nombre del punto (A, B, C, ...)
        point_name = chr(65 + point_counter)  # 65 es el código ASCII de 'A'
        print(f"\nIngrese las coordenadas para el punto {point_name}:")

        # Obtener coordenadas
        coord = get_coordinates_with_saved_options()
        points[point_name] = coord  # Guardar el punto en el diccionario

        # Preguntar si desea agregar otro punto
        while True:
            add_more = input(f"¿Desea agregar otro punto después de {point_name}? (s/n): ").strip().lower()
            if add_more in ["s", "n"]:
                break
            print("Por favor, ingrese 's' para sí o 'n' para no.")

        if add_more == "n":
            break  # Finalizar el bucle si el usuario no desea agregar más puntos

        point_counter += 1  # Incrementar el contador para el próximo punto

    return points

# %%
import random

def generate_random_color():
    """
    Genera un color hexadecimal aleatorio.
    """
    return f"#{random.randint(0, 255):02x}{random.randint(0, 255):02x}{random.randint(0, 255):02x}"

def plot_full_route_with_folium(G, nodes, routes, algorithm_name):
    """
    Genera un mapa para un algoritmo específico con puntos y rutas.
    """
    # Crear el mapa centrado en el primer punto
    first_point = list(nodes.values())[0]
    folium_map = folium.Map(
        location=[G.nodes[first_point]['y'], G.nodes[first_point]['x']],
        zoom_start=12,
        tiles='OpenStreetMap'
    )

    # Colores predefinidos para puntos
    predefined_colors = ["blue", "red", "green", "purple", "orange", "pink"]
    color_map = {}

    # Añadir puntos al mapa
    legend_items = []  # Para la leyenda
    for idx, (name, node) in enumerate(nodes.items()):
        if idx < len(predefined_colors):
            color = predefined_colors[idx]
        else:
            # Generar un color aleatorio si se exceden los colores predefinidos
            color = generate_random_color()
        color_map[name] = color  # Guardar el color asignado para la leyenda

        # Añadir el marcador del punto
        folium.Marker(
            location=[G.nodes[node]['y'], G.nodes[node]['x']],
            popup=f"Punto {name}",
            icon=folium.Icon(color=color if idx < len(predefined_colors) else "lightgray", icon="circle"),
        ).add_to(folium_map)

        # Añadir el punto a la leyenda
        legend_items.append(f"<span style='color:{color};'>Punto {name}</span>")

    # Añadir rutas al mapa
    for start_name, end_name, route_coordinates in routes:
        folium.PolyLine(
            route_coordinates,
            color="blue",  # Color de las rutas para el algoritmo
            weight=5,
            opacity=0.8,
            tooltip=f"Ruta de {start_name} a {end_name} ({algorithm_name})"
        ).add_to(folium_map)

    # Añadir leyenda al mapa
    legend_html = """
    <div style="position: fixed; bottom: 50px; left: 50px; z-index: 1000; background-color: white; padding: 10px; border: 2px solid black;">
    <h4>Leyenda</h4>
    """
    legend_html += "".join(f"<p style='margin:0'>{item}</p>" for item in legend_items)
    legend_html += "</div>"
    folium_map.get_root().html.add_child(folium.Element(legend_html))

    return folium_map

# %%
import os
import pickle

GRAPH_PATH = "tlaxcala_drive.pkl"

def load_tlaxcala_graph(network_type="drive"):
    graph_path = f"tlaxcala_{network_type}.pkl"
    if os.path.exists(graph_path):
        print("Cargando grafo desde disco...")
        with open(graph_path, "rb") as f:
            G = pickle.load(f)
    else:
        print("Descargando el grafo de Tlaxcala...")
        tlaxcala_graph = ox.graph_from_place("Tlaxcala, México", network_type=network_type)
        G = clean_graph(tlaxcala_graph, network_type)
        initialize_edge_styles(G)
        with open(graph_path, "wb") as f:
            pickle.dump(G, f)
        print("Grafo guardado en", graph_path)
    return G

# %%
import os
from concurrent.futures import ThreadPoolExecutor, ProcessPoolExecutor

def eval_task_light(args):
    start_node, end_node, start_name, end_name, network_type = args

    G_local = load_tlaxcala_graph(network_type=network_type)
    r = evaluate_pair(G_local, start_node, end_node, network_type=network_type)
    r["origen"] = start_name
    r["destino"] = end_name
    return r

def evaluate_pairs_parallel(G, nodes, point_names, network_type="drive", max_workers=4):
    tasks = []
    for i in range(len(point_names) - 1):
        sname = point_names[i]
        ename = point_names[i + 1]
        snode = nodes[sname]
        enode = nodes[ename]
        tasks.append((snode, enode, sname, ename, network_type))

    results = []

    Executor = ThreadPoolExecutor if os.name == "nt" else ProcessPoolExecutor

    with Executor(max_workers=max_workers) as ex:
        for r in ex.map(eval_task_light, tasks):
            results.append(r)

    return results

# %%
if __name__ == "__main__":
    
    try:
        print("Seleccione los puntos de la ruta:")
        points = get_multiple_points()
        print("\nPuntos ingresados:")
        for name, coord in points.items():
            print(f"  {name}: {coord}")
    
        # Tipo de transporte
        network_type = get_transport_type()
    
        # Cargar/descargar grafo
        G = load_tlaxcala_graph(network_type=network_type)

    
        # Obtener nodos más cercanos
        nodes = {}
        for name, coord in points.items():
            nodes[name] = ox.distance.nearest_nodes(G, coord[1], coord[0])
            print(f"Nodo más cercano al punto {name}: {nodes[name]}")
    
        point_names = list(points.keys())
    
        algorithms = {"Dijkstra": dijkstra, "A*": a_star}
        total_time = {"Dijkstra": 0, "A*": 0}
        total_distance = {"Dijkstra": 0, "A*": 0}
        routes_by_algorithm = {"Dijkstra": [], "A*": []}

        # ====== 1) MÉTRICAS EN PARALELO ======
        metrics_rows = evaluate_pairs_parallel(
            G,
            nodes,
            point_names,
            network_type=network_type,
            max_workers=4
        )
        # ====== FIN PARALELO ======
    
        # ====== 2) RECORRIDO NORMAL (PARA MAPAS Y TOTALES) ======
        for i in range(len(point_names) - 1):
            start_name = point_names[i]
            end_name = point_names[i + 1]
            print(f"\nCalculando la ruta de {start_name} a {end_name}...")
    
            start_node = nodes[start_name]
            end_node = nodes[end_name]
    
            for algorithm_name, algorithm in algorithms.items():
                print(f"Ejecutando el algoritmo {algorithm_name} de {start_name} a {end_name}...")
                try:
                    algorithm(G, start_node, end_node)
    
                    # reconstruir ruta
                    path = []
                    curr = end_node
                    while curr != start_node:
                        prev = G.nodes[curr]["previous"]
                        path.append((prev, curr))
                        curr = prev
                    path.reverse()
    
                    # distancia y tiempo estimado
                    try:
                        dist = sum(G.edges[u, v, 0]["length"] for u, v in path)
                        avg_speed = 40 if network_type == 'drive' else 5
                        time_est = (dist / 1000) / avg_speed * 60
    
                        total_distance[algorithm_name] += dist
                        total_time[algorithm_name] += time_est
    
                        print(f"{algorithm_name}:")
                        print(f"  Distancia estimada de {start_name} a {end_name}: {dist / 1000:.2f} km")
                        print(f"  Tiempo estimado de {start_name} a {end_name}: {time_est:.2f} minutos")
    
                        # guardar para folium
                        route_coordinates = get_route_coordinates(G, start_node, end_node)
                        routes_by_algorithm[algorithm_name].append(
                            (start_name, end_name, route_coordinates)
                        )
    
                    except Exception as e:
                        print(f"Error al calcular la distancia o tiempo para {algorithm_name}: {e}")
    
                except Exception as e:
                    print(f"Error durante la ejecución de {algorithm_name}: {e}")
        # ====== FIN RECORRIDO NORMAL ======
    
        # ====== 3) MOSTRAR MÉTRICAS ======
        if metrics_rows:
            df_eval = pd.DataFrame(metrics_rows)
            cols = [
                "origen", "destino",
                "dijkstra_time_ms", "astar_time_ms",
                "speedup_A*_vs_Dijkstra", "eficiencia",
                "dijkstra_dist_m", "astar_dist_m",
                "dijkstra_precision", "dijkstra_recall", "dijkstra_f1",
                "astar_precision", "astar_recall", "astar_f1"
            ]
            display(df_eval[cols])
    
            print("\n== Resumen global de métricas ==")
            print("Tiempo medio Dijkstra (ms):", df_eval["dijkstra_time_ms"].mean())
            print("Tiempo medio A* (ms):", df_eval["astar_time_ms"].mean())
            print("Speedup medio A* vs Dijkstra:",
                  (df_eval["dijkstra_time_ms"] / df_eval["astar_time_ms"]).mean())
            print("F1 Dijkstra:", df_eval["dijkstra_f1"].mean())
            print("F1 A*:", df_eval["astar_f1"].mean())
    
            df_eval.to_csv("resultados_iniciales_tlaxcala.csv", index=False)
        # ====== FIN MÉTRICAS ======
    
        # ====== 4) TOTALES ======
        print("\n--- Totales Finales ---")
        for algorithm_name in algorithms.keys():
            print(f"{algorithm_name}:")
            print(f"  Distancia total estimada: {total_distance[algorithm_name] / 1000:.2f} km")
            print(f"  Tiempo total estimado: {total_time[algorithm_name]:.2f} minutos")
    
        show_results_in_table(total_time, total_distance)
        # ====== FIN TOTALES ======
    
        # ====== 5) MAPAS ======
        for algorithm_name, routes in routes_by_algorithm.items():
            print(f"\nMostrando mapa para el algoritmo {algorithm_name}...")
            folium_map = plot_full_route_with_folium(G, nodes, routes, algorithm_name)
            display(folium_map)
        # ====== FIN MAPAS ======
    
    except Exception as e:
        print(f"Error general: {e}")
# Out:
# Seleccione los puntos de la ruta:
#
# Ingrese las coordenadas para el punto A:
#
# ¿Desea seleccionar un punto de la lista predefinida o ingresar coordenadas manualmente?
#   1. Seleccionar de la lista
#   2. Ingresar manualmente
# Seleccione una opción (1 o 2):  1
# Puntos disponibles:
#   1. UPIIT - Coordenadas: (19.323118, -98.233548)
#   2. Parque de Zacatelco - Coordenadas: (19.215691, -98.240524)
#   3. Soriana Ocotlan - Coordenadas: (19.318605, -98.220713)
#   4. Zoologico del Altiplano - Coordenadas: (19.338439, -98.199046)
#   5. Recinto Ferial - Coordenadas: (19.32500854887219, -98.24458295157108)
#   6. Escalinatas - Coordenadas: (19.3163317057408, -98.2432146346621)
#   7. Jardín botánico - Coordenadas: (19.328860233644402, -98.2186988643214)
#   8. Museo Nacional del Títere - Coordenadas: (19.31306644075224, -97.92325948735258)
#   9. Museo Taurino de Huamantla - Coordenadas: (19.315214643452563, -97.92088832789638)
#   10. Parque de Apizaco - Coordenadas: (19.41583668098076, -98.1404040514315)
#   11. Parque de Tlaxco - Coordenadas: (19.614479362946597, -98.11878748334519)
#   12. Centro Turístico Zacatelco - Coordenadas: (19.201482353314457, -98.250818177072)
#   13. Val'Quirico - Coordenadas: (19.19134212101139, -98.28932538116192)
#   14. Cacaxtla - Coordenadas: (19.244591586170426, -98.33845364678213)
# Seleccione un punto por su número:  1
# Ha seleccionado: UPIIT - Coordenadas: (19.323118, -98.233548)
# ¿Desea agregar otro punto después de A? (s/n):  s
# Ingrese las coordenadas para el punto B:
#
# ¿Desea seleccionar un punto de la lista predefinida o ingresar coordenadas manualmente?
#   1. Seleccionar de la lista
#   2. Ingresar manualmente
# Seleccione una opción (1 o 2):  1
# Puntos disponibles:
#   1. UPIIT - Coordenadas: (19.323118, -98.233548)
#   2. Parque de Zacatelco - Coordenadas: (19.215691, -98.240524)
#   3. Soriana Ocotlan - Coordenadas: (19.318605, -98.220713)
#   4. Zoologico del Altiplano - Coordenadas: (19.338439, -98.199046)
#   5. Recinto Ferial - Coordenadas: (19.32500854887219, -98.24458295157108)
#   6. Escalinatas - Coordenadas: (19.3163317057408, -98.2432146346621)
#   7. Jardín botánico - Coordenadas: (19.328860233644402, -98.2186988643214)
#   8. Museo Nacional del Títere - Coordenadas: (19.31306644075224, -97.92325948735258)
#   9. Museo Taurino de Huamantla - Coordenadas: (19.315214643452563, -97.92088832789638)
#   10. Parque de Apizaco - Coordenadas: (19.41583668098076, -98.1404040514315)
#   11. Parque de Tlaxco - Coordenadas: (19.614479362946597, -98.11878748334519)
#   12. Centro Turístico Zacatelco - Coordenadas: (19.201482353314457, -98.250818177072)
#   13. Val'Quirico - Coordenadas: (19.19134212101139, -98.28932538116192)
#   14. Cacaxtla - Coordenadas: (19.244591586170426, -98.33845364678213)
# Seleccione un punto por su número:  s
# Entrada inválida. Por favor, ingrese un número.
# Seleccione un punto por su número:  2
# Ha seleccionado: Parque de Zacatelco - Coordenadas: (19.215691, -98.240524)
# ¿Desea agregar otro punto después de B? (s/n):  s
# Ingrese las coordenadas para el punto C:
#
# ¿Desea seleccionar un punto de la lista predefinida o ingresar coordenadas manualmente?
#   1. Seleccionar de la lista
#   2. Ingresar manualmente
# Seleccione una opción (1 o 2):  1
# Puntos disponibles:
#   1. UPIIT - Coordenadas: (19.323118, -98.233548)
#   2. Parque de Zacatelco - Coordenadas: (19.215691, -98.240524)
#   3. Soriana Ocotlan - Coordenadas: (19.318605, -98.220713)
#   4. Zoologico del Altiplano - Coordenadas: (19.338439, -98.199046)
#   5. Recinto Ferial - Coordenadas: (19.32500854887219, -98.24458295157108)
#   6. Escalinatas - Coordenadas: (19.3163317057408, -98.2432146346621)
#   7. Jardín botánico - Coordenadas: (19.328860233644402, -98.2186988643214)
#   8. Museo Nacional del Títere - Coordenadas: (19.31306644075224, -97.92325948735258)
#   9. Museo Taurino de Huamantla - Coordenadas: (19.315214643452563, -97.92088832789638)
#   10. Parque de Apizaco - Coordenadas: (19.41583668098076, -98.1404040514315)
#   11. Parque de Tlaxco - Coordenadas: (19.614479362946597, -98.11878748334519)
#   12. Centro Turístico Zacatelco - Coordenadas: (19.201482353314457, -98.250818177072)
#   13. Val'Quirico - Coordenadas: (19.19134212101139, -98.28932538116192)
#   14. Cacaxtla - Coordenadas: (19.244591586170426, -98.33845364678213)
# Seleccione un punto por su número:  3
# Ha seleccionado: Soriana Ocotlan - Coordenadas: (19.318605, -98.220713)
# ¿Desea agregar otro punto después de C? (s/n):  s
# Ingrese las coordenadas para el punto D:
#
# ¿Desea seleccionar un punto de la lista predefinida o ingresar coordenadas manualmente?
#   1. Seleccionar de la lista
#   2. Ingresar manualmente
# Seleccione una opción (1 o 2):  1
# Puntos disponibles:
#   1. UPIIT - Coordenadas: (19.323118, -98.233548)
#   2. Parque de Zacatelco - Coordenadas: (19.215691, -98.240524)
#   3. Soriana Ocotlan - Coordenadas: (19.318605, -98.220713)
#   4. Zoologico del Altiplano - Coordenadas: (19.338439, -98.199046)
#   5. Recinto Ferial - Coordenadas: (19.32500854887219, -98.24458295157108)
#   6. Escalinatas - Coordenadas: (19.3163317057408, -98.2432146346621)
#   7. Jardín botánico - Coordenadas: (19.328860233644402, -98.2186988643214)
#   8. Museo Nacional del Títere - Coordenadas: (19.31306644075224, -97.92325948735258)
#   9. Museo Taurino de Huamantla - Coordenadas: (19.315214643452563, -97.92088832789638)
#   10. Parque de Apizaco - Coordenadas: (19.41583668098076, -98.1404040514315)
#   11. Parque de Tlaxco - Coordenadas: (19.614479362946597, -98.11878748334519)
#   12. Centro Turístico Zacatelco - Coordenadas: (19.201482353314457, -98.250818177072)
#   13. Val'Quirico - Coordenadas: (19.19134212101139, -98.28932538116192)
#   14. Cacaxtla - Coordenadas: (19.244591586170426, -98.33845364678213)
# Seleccione un punto por su número:  4
# Ha seleccionado: Zoologico del Altiplano - Coordenadas: (19.338439, -98.199046)
# ¿Desea agregar otro punto después de D? (s/n):  s
# Ingrese las coordenadas para el punto E:
#
# ¿Desea seleccionar un punto de la lista predefinida o ingresar coordenadas manualmente?
#   1. Seleccionar de la lista
#   2. Ingresar manualmente
# Seleccione una opción (1 o 2):  1
# Puntos disponibles:
#   1. UPIIT - Coordenadas: (19.323118, -98.233548)
#   2. Parque de Zacatelco - Coordenadas: (19.215691, -98.240524)
#   3. Soriana Ocotlan - Coordenadas: (19.318605, -98.220713)
#   4. Zoologico del Altiplano - Coordenadas: (19.338439, -98.199046)
#   5. Recinto Ferial - Coordenadas: (19.32500854887219, -98.24458295157108)
#   6. Escalinatas - Coordenadas: (19.3163317057408, -98.2432146346621)
#   7. Jardín botánico - Coordenadas: (19.328860233644402, -98.2186988643214)
#   8. Museo Nacional del Títere - Coordenadas: (19.31306644075224, -97.92325948735258)
#   9. Museo Taurino de Huamantla - Coordenadas: (19.315214643452563, -97.92088832789638)
#   10. Parque de Apizaco - Coordenadas: (19.41583668098076, -98.1404040514315)
#   11. Parque de Tlaxco - Coordenadas: (19.614479362946597, -98.11878748334519)
#   12. Centro Turístico Zacatelco - Coordenadas: (19.201482353314457, -98.250818177072)
#   13. Val'Quirico - Coordenadas: (19.19134212101139, -98.28932538116192)
#   14. Cacaxtla - Coordenadas: (19.244591586170426, -98.33845364678213)
# Seleccione un punto por su número:  5
# Ha seleccionado: Recinto Ferial - Coordenadas: (19.32500854887219, -98.24458295157108)
# ¿Desea agregar otro punto después de E? (s/n):  s
# Ingrese las coordenadas para el punto F:
#
# ¿Desea seleccionar un punto de la lista predefinida o ingresar coordenadas manualmente?
#   1. Seleccionar de la lista
#   2. Ingresar manualmente
# Seleccione una opción (1 o 2):  1
# Puntos disponibles:
#   1. UPIIT - Coordenadas: (19.323118, -98.233548)
#   2. Parque de Zacatelco - Coordenadas: (19.215691, -98.240524)
#   3. Soriana Ocotlan - Coordenadas: (19.318605, -98.220713)
#   4. Zoologico del Altiplano - Coordenadas: (19.338439, -98.199046)
#   5. Recinto Ferial - Coordenadas: (19.32500854887219, -98.24458295157108)
#   6. Escalinatas - Coordenadas: (19.3163317057408, -98.2432146346621)
#   7. Jardín botánico - Coordenadas: (19.328860233644402, -98.2186988643214)
#   8. Museo Nacional del Títere - Coordenadas: (19.31306644075224, -97.92325948735258)
#   9. Museo Taurino de Huamantla - Coordenadas: (19.315214643452563, -97.92088832789638)
#   10. Parque de Apizaco - Coordenadas: (19.41583668098076, -98.1404040514315)
#   11. Parque de Tlaxco - Coordenadas: (19.614479362946597, -98.11878748334519)
#   12. Centro Turístico Zacatelco - Coordenadas: (19.201482353314457, -98.250818177072)
#   13. Val'Quirico - Coordenadas: (19.19134212101139, -98.28932538116192)
#   14. Cacaxtla - Coordenadas: (19.244591586170426, -98.33845364678213)
# Seleccione un punto por su número:  6
# Ha seleccionado: Escalinatas - Coordenadas: (19.3163317057408, -98.2432146346621)
# ¿Desea agregar otro punto después de F? (s/n):  s
# Ingrese las coordenadas para el punto G:
#
# ¿Desea seleccionar un punto de la lista predefinida o ingresar coordenadas manualmente?
#   1. Seleccionar de la lista
#   2. Ingresar manualmente
# Seleccione una opción (1 o 2):  1
# Puntos disponibles:
#   1. UPIIT - Coordenadas: (19.323118, -98.233548)
#   2. Parque de Zacatelco - Coordenadas: (19.215691, -98.240524)
#   3. Soriana Ocotlan - Coordenadas: (19.318605, -98.220713)
#   4. Zoologico del Altiplano - Coordenadas: (19.338439, -98.199046)
#   5. Recinto Ferial - Coordenadas: (19.32500854887219, -98.24458295157108)
#   6. Escalinatas - Coordenadas: (19.3163317057408, -98.2432146346621)
#   7. Jardín botánico - Coordenadas: (19.328860233644402, -98.2186988643214)
#   8. Museo Nacional del Títere - Coordenadas: (19.31306644075224, -97.92325948735258)
#   9. Museo Taurino de Huamantla - Coordenadas: (19.315214643452563, -97.92088832789638)
#   10. Parque de Apizaco - Coordenadas: (19.41583668098076, -98.1404040514315)
#   11. Parque de Tlaxco - Coordenadas: (19.614479362946597, -98.11878748334519)
#   12. Centro Turístico Zacatelco - Coordenadas: (19.201482353314457, -98.250818177072)
#   13. Val'Quirico - Coordenadas: (19.19134212101139, -98.28932538116192)
#   14. Cacaxtla - Coordenadas: (19.244591586170426, -98.33845364678213)
# Seleccione un punto por su número:  7
# Ha seleccionado: Jardín botánico - Coordenadas: (19.328860233644402, -98.2186988643214)
# ¿Desea agregar otro punto después de G? (s/n):  s
# Ingrese las coordenadas para el punto H:
#
# ¿Desea seleccionar un punto de la lista predefinida o ingresar coordenadas manualmente?
#   1. Seleccionar de la lista
#   2. Ingresar manualmente
# Seleccione una opción (1 o 2):  1
# Puntos disponibles:
#   1. UPIIT - Coordenadas: (19.323118, -98.233548)
#   2. Parque de Zacatelco - Coordenadas: (19.215691, -98.240524)
#   3. Soriana Ocotlan - Coordenadas: (19.318605, -98.220713)
#   4. Zoologico del Altiplano - Coordenadas: (19.338439, -98.199046)
#   5. Recinto Ferial - Coordenadas: (19.32500854887219, -98.24458295157108)
#   6. Escalinatas - Coordenadas: (19.3163317057408, -98.2432146346621)
#   7. Jardín botánico - Coordenadas: (19.328860233644402, -98.2186988643214)
#   8. Museo Nacional del Títere - Coordenadas: (19.31306644075224, -97.92325948735258)
#   9. Museo Taurino de Huamantla - Coordenadas: (19.315214643452563, -97.92088832789638)
#   10. Parque de Apizaco - Coordenadas: (19.41583668098076, -98.1404040514315)
#   11. Parque de Tlaxco - Coordenadas: (19.614479362946597, -98.11878748334519)
#   12. Centro Turístico Zacatelco - Coordenadas: (19.201482353314457, -98.250818177072)
#   13. Val'Quirico - Coordenadas: (19.19134212101139, -98.28932538116192)
#   14. Cacaxtla - Coordenadas: (19.244591586170426, -98.33845364678213)
# Seleccione un punto por su número:  8
# Ha seleccionado: Museo Nacional del Títere - Coordenadas: (19.31306644075224, -97.92325948735258)
# ¿Desea agregar otro punto después de H? (s/n):  s
# Ingrese las coordenadas para el punto I:
#
# ¿Desea seleccionar un punto de la lista predefinida o ingresar coordenadas manualmente?
#   1. Seleccionar de la lista
#   2. Ingresar manualmente
# Seleccione una opción (1 o 2):  1
# Puntos disponibles:
#   1. UPIIT - Coordenadas: (19.323118, -98.233548)
#   2. Parque de Zacatelco - Coordenadas: (19.215691, -98.240524)
#   3. Soriana Ocotlan - Coordenadas: (19.318605, -98.220713)
#   4. Zoologico del Altiplano - Coordenadas: (19.338439, -98.199046)
#   5. Recinto Ferial - Coordenadas: (19.32500854887219, -98.24458295157108)
#   6. Escalinatas - Coordenadas: (19.3163317057408, -98.2432146346621)
#   7. Jardín botánico - Coordenadas: (19.328860233644402, -98.2186988643214)
#   8. Museo Nacional del Títere - Coordenadas: (19.31306644075224, -97.92325948735258)
#   9. Museo Taurino de Huamantla - Coordenadas: (19.315214643452563, -97.92088832789638)
#   10. Parque de Apizaco - Coordenadas: (19.41583668098076, -98.1404040514315)
#   11. Parque de Tlaxco - Coordenadas: (19.614479362946597, -98.11878748334519)
#   12. Centro Turístico Zacatelco - Coordenadas: (19.201482353314457, -98.250818177072)
#   13. Val'Quirico - Coordenadas: (19.19134212101139, -98.28932538116192)
#   14. Cacaxtla - Coordenadas: (19.244591586170426, -98.33845364678213)
# Seleccione un punto por su número:  9
# Ha seleccionado: Museo Taurino de Huamantla - Coordenadas: (19.315214643452563, -97.92088832789638)
# ¿Desea agregar otro punto después de I? (s/n):  s
# Ingrese las coordenadas para el punto J:
#
# ¿Desea seleccionar un punto de la lista predefinida o ingresar coordenadas manualmente?
#   1. Seleccionar de la lista
#   2. Ingresar manualmente
# Seleccione una opción (1 o 2):  1
# Puntos disponibles:
#   1. UPIIT - Coordenadas: (19.323118, -98.233548)
#   2. Parque de Zacatelco - Coordenadas: (19.215691, -98.240524)
#   3. Soriana Ocotlan - Coordenadas: (19.318605, -98.220713)
#   4. Zoologico del Altiplano - Coordenadas: (19.338439, -98.199046)
#   5. Recinto Ferial - Coordenadas: (19.32500854887219, -98.24458295157108)
#   6. Escalinatas - Coordenadas: (19.3163317057408, -98.2432146346621)
#   7. Jardín botánico - Coordenadas: (19.328860233644402, -98.2186988643214)
#   8. Museo Nacional del Títere - Coordenadas: (19.31306644075224, -97.92325948735258)
#   9. Museo Taurino de Huamantla - Coordenadas: (19.315214643452563, -97.92088832789638)
#   10. Parque de Apizaco - Coordenadas: (19.41583668098076, -98.1404040514315)
#   11. Parque de Tlaxco - Coordenadas: (19.614479362946597, -98.11878748334519)
#   12. Centro Turístico Zacatelco - Coordenadas: (19.201482353314457, -98.250818177072)
#   13. Val'Quirico - Coordenadas: (19.19134212101139, -98.28932538116192)
#   14. Cacaxtla - Coordenadas: (19.244591586170426, -98.33845364678213)
# Seleccione un punto por su número:  10
# Ha seleccionado: Parque de Apizaco - Coordenadas: (19.41583668098076, -98.1404040514315)
# ¿Desea agregar otro punto después de J? (s/n):  s
# Ingrese las coordenadas para el punto K:
#
# ¿Desea seleccionar un punto de la lista predefinida o ingresar coordenadas manualmente?
#   1. Seleccionar de la lista
#   2. Ingresar manualmente
# Seleccione una opción (1 o 2):  1
# Puntos disponibles:
#   1. UPIIT - Coordenadas: (19.323118, -98.233548)
#   2. Parque de Zacatelco - Coordenadas: (19.215691, -98.240524)
#   3. Soriana Ocotlan - Coordenadas: (19.318605, -98.220713)
#   4. Zoologico del Altiplano - Coordenadas: (19.338439, -98.199046)
#   5. Recinto Ferial - Coordenadas: (19.32500854887219, -98.24458295157108)
#   6. Escalinatas - Coordenadas: (19.3163317057408, -98.2432146346621)
#   7. Jardín botánico - Coordenadas: (19.328860233644402, -98.2186988643214)
#   8. Museo Nacional del Títere - Coordenadas: (19.31306644075224, -97.92325948735258)
#   9. Museo Taurino de Huamantla - Coordenadas: (19.315214643452563, -97.92088832789638)
#   10. Parque de Apizaco - Coordenadas: (19.41583668098076, -98.1404040514315)
#   11. Parque de Tlaxco - Coordenadas: (19.614479362946597, -98.11878748334519)
#   12. Centro Turístico Zacatelco - Coordenadas: (19.201482353314457, -98.250818177072)
#   13. Val'Quirico - Coordenadas: (19.19134212101139, -98.28932538116192)
#   14. Cacaxtla - Coordenadas: (19.244591586170426, -98.33845364678213)
# Seleccione un punto por su número:  11
# Ha seleccionado: Parque de Tlaxco - Coordenadas: (19.614479362946597, -98.11878748334519)
# ¿Desea agregar otro punto después de K? (s/n):  s
# Ingrese las coordenadas para el punto L:
#
# ¿Desea seleccionar un punto de la lista predefinida o ingresar coordenadas manualmente?
#   1. Seleccionar de la lista
#   2. Ingresar manualmente
# Seleccione una opción (1 o 2):  1
# Puntos disponibles:
#   1. UPIIT - Coordenadas: (19.323118, -98.233548)
#   2. Parque de Zacatelco - Coordenadas: (19.215691, -98.240524)
#   3. Soriana Ocotlan - Coordenadas: (19.318605, -98.220713)
#   4. Zoologico del Altiplano - Coordenadas: (19.338439, -98.199046)
#   5. Recinto Ferial - Coordenadas: (19.32500854887219, -98.24458295157108)
#   6. Escalinatas - Coordenadas: (19.3163317057408, -98.2432146346621)
#   7. Jardín botánico - Coordenadas: (19.328860233644402, -98.2186988643214)
#   8. Museo Nacional del Títere - Coordenadas: (19.31306644075224, -97.92325948735258)
#   9. Museo Taurino de Huamantla - Coordenadas: (19.315214643452563, -97.92088832789638)
#   10. Parque de Apizaco - Coordenadas: (19.41583668098076, -98.1404040514315)
#   11. Parque de Tlaxco - Coordenadas: (19.614479362946597, -98.11878748334519)
#   12. Centro Turístico Zacatelco - Coordenadas: (19.201482353314457, -98.250818177072)
#   13. Val'Quirico - Coordenadas: (19.19134212101139, -98.28932538116192)
#   14. Cacaxtla - Coordenadas: (19.244591586170426, -98.33845364678213)
# Seleccione un punto por su número:  12
# Ha seleccionado: Centro Turístico Zacatelco - Coordenadas: (19.201482353314457, -98.250818177072)
# ¿Desea agregar otro punto después de L? (s/n):  s
# Ingrese las coordenadas para el punto M:
#
# ¿Desea seleccionar un punto de la lista predefinida o ingresar coordenadas manualmente?
#   1. Seleccionar de la lista
#   2. Ingresar manualmente
# Seleccione una opción (1 o 2):  1
# Puntos disponibles:
#   1. UPIIT - Coordenadas: (19.323118, -98.233548)
#   2. Parque de Zacatelco - Coordenadas: (19.215691, -98.240524)
#   3. Soriana Ocotlan - Coordenadas: (19.318605, -98.220713)
#   4. Zoologico del Altiplano - Coordenadas: (19.338439, -98.199046)
#   5. Recinto Ferial - Coordenadas: (19.32500854887219, -98.24458295157108)
#   6. Escalinatas - Coordenadas: (19.3163317057408, -98.2432146346621)
#   7. Jardín botánico - Coordenadas: (19.328860233644402, -98.2186988643214)
#   8. Museo Nacional del Títere - Coordenadas: (19.31306644075224, -97.92325948735258)
#   9. Museo Taurino de Huamantla - Coordenadas: (19.315214643452563, -97.92088832789638)
#   10. Parque de Apizaco - Coordenadas: (19.41583668098076, -98.1404040514315)
#   11. Parque de Tlaxco - Coordenadas: (19.614479362946597, -98.11878748334519)
#   12. Centro Turístico Zacatelco - Coordenadas: (19.201482353314457, -98.250818177072)
#   13. Val'Quirico - Coordenadas: (19.19134212101139, -98.28932538116192)
#   14. Cacaxtla - Coordenadas: (19.244591586170426, -98.33845364678213)
# Seleccione un punto por su número:  13
# Ha seleccionado: Val'Quirico - Coordenadas: (19.19134212101139, -98.28932538116192)
# ¿Desea agregar otro punto después de M? (s/n):  s
# Ingrese las coordenadas para el punto N:
#
# ¿Desea seleccionar un punto de la lista predefinida o ingresar coordenadas manualmente?
#   1. Seleccionar de la lista
#   2. Ingresar manualmente
# Seleccione una opción (1 o 2):  1
# Puntos disponibles:
#   1. UPIIT - Coordenadas: (19.323118, -98.233548)
#   2. Parque de Zacatelco - Coordenadas: (19.215691, -98.240524)
#   3. Soriana Ocotlan - Coordenadas: (19.318605, -98.220713)
#   4. Zoologico del Altiplano - Coordenadas: (19.338439, -98.199046)
#   5. Recinto Ferial - Coordenadas: (19.32500854887219, -98.24458295157108)
#   6. Escalinatas - Coordenadas: (19.3163317057408, -98.2432146346621)
#   7. Jardín botánico - Coordenadas: (19.328860233644402, -98.2186988643214)
#   8. Museo Nacional del Títere - Coordenadas: (19.31306644075224, -97.92325948735258)
#   9. Museo Taurino de Huamantla - Coordenadas: (19.315214643452563, -97.92088832789638)
#   10. Parque de Apizaco - Coordenadas: (19.41583668098076, -98.1404040514315)
#   11. Parque de Tlaxco - Coordenadas: (19.614479362946597, -98.11878748334519)
#   12. Centro Turístico Zacatelco - Coordenadas: (19.201482353314457, -98.250818177072)
#   13. Val'Quirico - Coordenadas: (19.19134212101139, -98.28932538116192)
#   14. Cacaxtla - Coordenadas: (19.244591586170426, -98.33845364678213)
# Seleccione un punto por su número:  14
# Ha seleccionado: Cacaxtla - Coordenadas: (19.244591586170426, -98.33845364678213)
# ¿Desea agregar otro punto después de N? (s/n):  n
# Puntos ingresados:
#   A: (19.323118, -98.233548)
#   B: (19.215691, -98.240524)
#   C: (19.318605, -98.220713)
#   D: (19.338439, -98.199046)
#   E: (19.32500854887219, -98.24458295157108)
#   F: (19.3163317057408, -98.2432146346621)
#   G: (19.328860233644402, -98.2186988643214)
#   H: (19.31306644075224, -97.92325948735258)
#   I: (19.315214643452563, -97.92088832789638)
#   J: (19.41583668098076, -98.1404040514315)
#   K: (19.614479362946597, -98.11878748334519)
#   L: (19.201482353314457, -98.250818177072)
#   M: (19.19134212101139, -98.28932538116192)
#   N: (19.244591586170426, -98.33845364678213)
# Ingrese el tipo de viaje que realizará:
#   1. Auto
#   2. Caminando
# Seleccione una opción (1 o 2):  1
# Cargando grafo desde disco...
# Nodo más cercano al punto A: 360340293
# Nodo más cercano al punto B: 1108112797
# Nodo más cercano al punto C: 352143711
# Nodo más cercano al punto D: 7152042014
# Nodo más cercano al punto E: 350372058
# Nodo más cercano al punto F: 349741597
# Nodo más cercano al punto G: 1088997650
# Nodo más cercano al punto H: 355222235
# Nodo más cercano al punto I: 355293568
# Nodo más cercano al punto J: 361721404
# Nodo más cercano al punto K: 7887774669
# Nodo más cercano al punto L: 354985210
# Nodo más cercano al punto M: 367499828
# Nodo más cercano al punto N: 1129150091
# Cargando grafo desde disco...
# Cargando grafo desde disco...
# Cargando grafo desde disco...
# Cargando grafo desde disco...
# [WARN] No se pudo ajustar tráfico en 7152042014->1713724183: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.3381716%2C-98.1991857
# [WARN] No se pudo ajustar tráfico en 1713724183->353573669: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.3382696%2C-98.1994811
# [WARN] No se pudo ajustar tráfico en 1108112797->351043804: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.2153912%2C-98.2408413
# [WARN] No se pudo ajustar tráfico en 360340293->348876898: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.3229731%2C-98.2330294
# [WARN] No se pudo ajustar tráfico en 353573669->1090296123: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.3358515%2C-98.1986781
# [WARN] No se pudo ajustar tráfico en 351043804->351036742: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.2151317%2C-98.2403937
# [WARN] No se pudo ajustar tráfico en 348876898->349742602: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.3224087%2C-98.2341189
# [WARN] No se pudo ajustar tráfico en 1090296123->1090296064: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.3358033%2C-98.1994371
# [WARN] No se pudo ajustar tráfico en 352143711->352143229: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.3189998%2C-98.2209824
# [WARN] No se pudo ajustar tráfico en 351036742->351044983: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.2143214%2C-98.2389536
# [WARN] No se pudo ajustar tráfico en 349742602->349737132: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.3231441%2C-98.2354729
# [WARN] No se pudo ajustar tráfico en 1090296064->8481604565: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.3346898%2C-98.2000672
# [WARN] No se pudo ajustar tráfico en 352143229->352142946: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.3193374%2C-98.2211576
# [WARN] No se pudo ajustar tráfico en 349737132->350694080: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.3219804%2C-98.2361938
# [WARN] No se pudo ajustar tráfico en 351044983->351016136: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.2147438%2C-98.2386485
# [WARN] No se pudo ajustar tráfico en 8481604565->1090296072: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.3352008%2C-98.2011429
# [WARN] No se pudo ajustar tráfico en 352142946->8488853876: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.320376%2C-98.2217208
# [WARN] No se pudo ajustar tráfico en 350694080->349737136: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.3207443%2C-98.2369411
# [WARN] No se pudo ajustar tráfico en 351016136->8841822658: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.2149511%2C-98.2385062
# [WARN] No se pudo ajustar tráfico en 1090296072->1090296282: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.3356501%2C-98.2017139
# [WARN] No se pudo ajustar tráfico en 8488853876->352141918: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.3207071%2C-98.221934
# [WARN] No se pudo ajustar tráfico en 349737136->349737141: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.319537%2C-98.2376863
# [WARN] No se pudo ajustar tráfico en 8841822658->293191217: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.2162007%2C-98.2406819
# [WARN] No se pudo ajustar tráfico en 1090296282->7909113509: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.336343%2C-98.2025307
# [WARN] No se pudo ajustar tráfico en 352141918->352141754: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.320752%2C-98.2219729
# [WARN] No se pudo ajustar tráfico en 349737141->350694048: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.3183496%2C-98.2384422
# [WARN] No se pudo ajustar tráfico en 293191217->351039250: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.2167151%2C-98.2402571
# [WARN] No se pudo ajustar tráfico en 7909113509->7909113505: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.3365751%2C-98.2027976
# [WARN] No se pudo ajustar tráfico en 352141754->352141428: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.3210107%2C-98.2221623
# [WARN] No se pudo ajustar tráfico en 350694048->350691642: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.3187444%2C-98.2391468
# [WARN] No se pudo ajustar tráfico en 351039250->1600698899: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.2170265%2C-98.2407812
# [WARN] No se pudo ajustar tráfico en 7909113505->7909113503: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.336829%2C-98.2030895
# [WARN] No se pudo ajustar tráfico en 352141428->352141276: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.3212528%2C-98.2223445
# [WARN] No se pudo ajustar tráfico en 350691642->350691860: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.3182318%2C-98.2394997
# [WARN] No se pudo ajustar tráfico en 1600698899->808012435: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.2170962%2C-98.2408512
# [WARN] No se pudo ajustar tráfico en 7909113503->8481950790: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.3370394%2C-98.2033315
# [WARN] No se pudo ajustar tráfico en 352141276->7918714163: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.3215071%2C-98.2225359
# [WARN] No se pudo ajustar tráfico en 350691860->349667668: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.3168504%2C-98.2394089
# [WARN] No se pudo ajustar tráfico en 808012435->364094878: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.2181521%2C-98.2413986
# [WARN] No se pudo ajustar tráfico en 8481950790->1100936059: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.3332372%2C-98.2118962
# [WARN] No se pudo ajustar tráfico en 7918714163->7918677310: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.3215653%2C-98.2225815
# [WARN] No se pudo ajustar tráfico en 349667668->349669169: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.3149096%2C-98.2405928
# [WARN] No se pudo ajustar tráfico en 364094878->351053261: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.2186765%2C-98.2416227
# [WARN] No se pudo ajustar tráfico en 1100936059->7917929903: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.332633%2C-98.2137048
# [WARN] No se pudo ajustar tráfico en 7918677310->350414313: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.3219198%2C-98.2228466
# [WARN] No se pudo ajustar tráfico en 349669169->366730498: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.3133854%2C-98.2403719
# [WARN] No se pudo ajustar tráfico en 351053261->7917764387: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.2190477%2C-98.2417871
# [WARN] No se pudo ajustar tráfico en 7917929903->1088958313: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.3318218%2C-98.2136334
# [WARN] No se pudo ajustar tráfico en 350414313->7918714164: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.3220547%2C-98.2229482
# [WARN] No se pudo ajustar tráfico en 366730498->366729848: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.3114095%2C-98.2407717
# [WARN] No se pudo ajustar tráfico en 7917764387->351054533: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.2195134%2C-98.2420204
# [WARN] No se pudo ajustar tráfico en 1088958313->353573553: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.3309804%2C-98.2147173
# [WARN] No se pudo ajustar tráfico en 7918714164->352138904: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.3224067%2C-98.2231585
# [WARN] No se pudo ajustar tráfico en 366729848->7921394917: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.3114324%2C-98.2409912
# [WARN] No se pudo ajustar tráfico en 351054533->351042182: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.2202713%2C-98.2423896
# [WARN] No se pudo ajustar tráfico en 353573553->8405930284: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.3304737%2C-98.213475
# [WARN] No se pudo ajustar tráfico en 352138904->1588753153: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.3224414%2C-98.2205005
# [WARN] No se pudo ajustar tráfico en 7921394917->366730497: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.3108792%2C-98.2410944
# [WARN] No se pudo ajustar tráfico en 351042182->351056857: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.2209148%2C-98.2427173
# [WARN] No se pudo ajustar tráfico en 366730497->366729952: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.3105478%2C-98.2412026
# [WARN] No se pudo ajustar tráfico en 8405930284->353573554: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.3286725%2C-98.2141645
# [WARN] No se pudo ajustar tráfico en 1588753153->352140096: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.3232325%2C-98.2195539
# [WARN] No se pudo ajustar tráfico en 351056857->354987986: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.2213688%2C-98.242919
# [WARN] No se pudo ajustar tráfico en 366729952->357779292: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.310227%2C-98.2415311
# [WARN] No se pudo ajustar tráfico en 353573554->1088958357: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.3285947%2C-98.214188
# [WARN] No se pudo ajustar tráfico en 352140096->352138792: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.3235859%2C-98.2191491
# [WARN] No se pudo ajustar tráfico en 354987986->351039579: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.2215171%2C-98.2429904
# [WARN] No se pudo ajustar tráfico en 357779292->357779307: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.3107928%2C-98.2415539
# [WARN] No se pudo ajustar tráfico en 352138792->356365445: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.3239098%2C-98.2187735
# [WARN] No se pudo ajustar tráfico en 1088958357->8831613144: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.328704%2C-98.2149645
# [WARN] No se pudo ajustar tráfico en 351039579->8835226258: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.221802%2C-98.2431031
# [WARN] No se pudo ajustar tráfico en 8831613144->1088997650: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.3287578%2C-98.215551
# [WARN] No se pudo ajustar tráfico en 356365445->356365433: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.3262218%2C-98.2196142
# [WARN] No se pudo ajustar tráfico en 357779307->350241200: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.3108578%2C-98.2416712
# [WARN] No se pudo ajustar tráfico en 8835226258->7914535718: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.2223254%2C-98.2433427
# [WARN] No se pudo ajustar tráfico en 1088997650->348876895: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.3288692%2C-98.219007
# [WARN] No se pudo ajustar tráfico en 350241200->1136074768: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.3102434%2C-98.2416354
# [WARN] No se pudo ajustar tráfico en 356365433->356365411: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.3265803%2C-98.219215
# [WARN] No se pudo ajustar tráfico en 7914535718->1206460417: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.2228892%2C-98.2436007
# [WARN] No se pudo ajustar tráfico en 348876895->7714995305: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.3288651%2C-98.2193445
# [WARN] No se pudo ajustar tráfico en 356365411->356365259: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.3274039%2C-98.218188
# [WARN] No se pudo ajustar tráfico en 1136074768->1136075403: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.309661%2C-98.2416015
# [WARN] No se pudo ajustar tráfico en 1206460417->365211766: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.2234297%2C-98.2438936
# [WARN] No se pudo ajustar tráfico en 1136075403->1206141943: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.3090357%2C-98.241565
# [WARN] No se pudo ajustar tráfico en 356365259->356365517: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.3270248%2C-98.2178915
# [WARN] No se pudo ajustar tráfico en 7714995305->7715073635: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.3290783%2C-98.2210462
# [WARN] No se pudo ajustar tráfico en 365211766->365211765: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.2235597%2C-98.243945
# [WARN] No se pudo ajustar tráfico en 7715073635->348876896: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.3290904%2C-98.2212195
# [WARN] No se pudo ajustar tráfico en 1206141943->1206141930: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.3084136%2C-98.2415287
# [WARN] No se pudo ajustar tráfico en 356365517->360340378: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.3268346%2C-98.2177427
# [WARN] No se pudo ajustar tráfico en 365211765->354989358: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.2242157%2C-98.2434275
# [WARN] No se pudo ajustar tráfico en 348876896->356364949: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.3291811%2C-98.2248531
# [WARN] No se pudo ajustar tráfico en 360340378->7917462994: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.3261543%2C-98.2169995
# [WARN] No se pudo ajustar tráfico en 1206141930->350241205: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.3077954%2C-98.2414917
# [WARN] No se pudo ajustar tráfico en 354989358->8834857483: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.2238774%2C-98.242876
# [WARN] No se pudo ajustar tráfico en 7917462994->356160919: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.3256974%2C-98.215785
# [WARN] No se pudo ajustar tráfico en 350241205->350243717: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.307441%2C-98.241463
# [WARN] No se pudo ajustar tráfico en 356364949->356364969: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.3280424%2C-98.2262692
# [WARN] No se pudo ajustar tráfico en 8834857483->354989357: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.2247461%2C-98.2421835
# [WARN] No se pudo ajustar tráfico en 356364969->7918583175: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.3291138%2C-98.2274813
# [WARN] No se pudo ajustar tráfico en 356160919->1088997648: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.3249785%2C-98.2152393
# [WARN] No se pudo ajustar tráfico en 350243717->1206141907: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.3071724%2C-98.2414491
# [WARN] No se pudo ajustar tráfico en 354989357->7914451890: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.2253244%2C-98.2417224
# [WARN] No se pudo ajustar tráfico en 1088997648->356160914: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.3248413%2C-98.2151248
# [WARN] No se pudo ajustar tráfico en 1206141907->350241216: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.3065877%2C-98.2414092
# [WARN] No se pudo ajustar tráfico en 7918583175->349743000: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.3290311%2C-98.2276493
# [WARN] No se pudo ajustar tráfico en 7914451890->8834857498: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.2256279%2C-98.2420985
# [WARN] No se pudo ajustar tráfico en 349743000->350694286: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.3269036%2C-98.2301701[WARN] No se pudo ajustar tráfico en 350241216->350238809: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.3059658%2C-98.2413628
#
# [WARN] No se pudo ajustar tráfico en 356160914->1088997700: 403 Client Error: Forbidden for url: https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json?key=hUTvL90sHfWvbgxP7xdvDRqj0piT8SAq&point=19.3239279%2C-98.2142046
# ...
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1c36be9753086bed93ea6b550b6a8ad9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;div style=&quot;position: fixed; bottom: 50px; left: 50px; z-index: 1000; background-color: white; padding: 10px; border: 2px solid black;&quot;&gt;
#     &lt;h4&gt;Leyenda&lt;/h4&gt;
#     &lt;p style=&#x27;margin:0&#x27;&gt;&lt;span style=&#x27;color:blue;&#x27;&gt;Punto A&lt;/span&gt;&lt;/p&gt;&lt;p style=&#x27;margin:0&#x27;&gt;&lt;span style=&#x27;color:red;&#x27;&gt;Punto B&lt;/span&gt;&lt;/p&gt;&lt;p style=&#x27;margin:0&#x27;&gt;&lt;span style=&#x27;color:green;&#x27;&gt;Punto C&lt;/span&gt;&lt;/p&gt;&lt;p style=&#x27;margin:0&#x27;&gt;&lt;span style=&#x27;color:purple;&#x27;&gt;Punto D&lt;/span&gt;&lt;/p&gt;&lt;/div&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1c36be9753086bed93ea6b550b6a8ad9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1c36be9753086bed93ea6b550b6a8ad9 = L.map(
#                 &quot;map_1c36be9753086bed93ea6b550b6a8ad9&quot;,
#                 {
#                     center: [19.3229731, -98.2330294],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_aad0c0ab8551f1532ed024346bbf7895 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_aad0c0ab8551f1532ed024346bbf7895.addTo(map_1c36be9753086bed93ea6b550b6a8ad9);
#
#
#             var marker_f77c68cadc7db0f588e4ec523794b72f = L.marker(
#                 [19.3229731, -98.2330294],
#                 {
# }
#             ).addTo(map_1c36be9753086bed93ea6b550b6a8ad9);
#
#
#             var icon_70b1c110b4e7c2ca3eadda8d47002dc3 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;circle&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_dcb0a7b88e195632209e569ee632b1ef = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4fa1ef8c72c04ade120f0a6166f191a6 = $(`&lt;div id=&quot;html_4fa1ef8c72c04ade120f0a6166f191a6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Punto A&lt;/div&gt;`)[0];
#                 popup_dcb0a7b88e195632209e569ee632b1ef.setContent(html_4fa1ef8c72c04ade120f0a6166f191a6);
#
#
#
#         marker_f77c68cadc7db0f588e4ec523794b72f.bindPopup(popup_dcb0a7b88e195632209e569ee632b1ef)
#         ;
#
#
#
#
#                 marker_f77c68cadc7db0f588e4ec523794b72f.setIcon(icon_70b1c110b4e7c2ca3eadda8d47002dc3);
#
#
#             var marker_7f7756127a9c874c0b2bcb2567fae88d = L.marker(
#                 [19.2153912, -98.2408413],
#                 {
# }
#             ).addTo(map_1c36be9753086bed93ea6b550b6a8ad9);
#
#
#             var icon_38f848e77e1261b18e2863effb5de571 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;circle&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_b6bc4ee52adf374c8ac17c0636d5b46f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f7533cc6d5367f297b3a567ee259b509 = $(`&lt;div id=&quot;html_f7533cc6d5367f297b3a567ee259b509&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Punto B&lt;/div&gt;`)[0];
#                 popup_b6bc4ee52adf374c8ac17c0636d5b46f.setContent(html_f7533cc6d5367f297b3a567ee259b509);
#
#
#
#         marker_7f7756127a9c874c0b2bcb2567fae88d.bindPopup(popup_b6bc4ee52adf374c8ac17c0636d5b46f)
#         ;
#
#
#
#
#                 marker_7f7756127a9c874c0b2bcb2567fae88d.setIcon(icon_38f848e77e1261b18e2863effb5de571);
#
#
#             var marker_ed7ff0fc54334e7311739270c367ef12 = L.marker(
#                 [19.3189998, -98.2209824],
#                 {
# }
#             ).addTo(map_1c36be9753086bed93ea6b550b6a8ad9);
#
#
#             var icon_24d0f6af9ed5f7754b0b17aa6f025ddf = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;circle&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_ed532c5d0579c883224b9ac0730e2382 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
# Mostrando mapa para el algoritmo A*...
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_145cf48466f118fa12fcdd140b6ba329 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;div style=&quot;position: fixed; bottom: 50px; left: 50px; z-index: 1000; background-color: white; padding: 10px; border: 2px solid black;&quot;&gt;
#     &lt;h4&gt;Leyenda&lt;/h4&gt;
#     &lt;p style=&#x27;margin:0&#x27;&gt;&lt;span style=&#x27;color:blue;&#x27;&gt;Punto A&lt;/span&gt;&lt;/p&gt;&lt;p style=&#x27;margin:0&#x27;&gt;&lt;span style=&#x27;color:red;&#x27;&gt;Punto B&lt;/span&gt;&lt;/p&gt;&lt;p style=&#x27;margin:0&#x27;&gt;&lt;span style=&#x27;color:green;&#x27;&gt;Punto C&lt;/span&gt;&lt;/p&gt;&lt;p style=&#x27;margin:0&#x27;&gt;&lt;span style=&#x27;color:purple;&#x27;&gt;Punto D&lt;/span&gt;&lt;/p&gt;&lt;/div&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_145cf48466f118fa12fcdd140b6ba329&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_145cf48466f118fa12fcdd140b6ba329 = L.map(
#                 &quot;map_145cf48466f118fa12fcdd140b6ba329&quot;,
#                 {
#                     center: [19.3229731, -98.2330294],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_01164d306757fa353bf40446e2c87c4b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_01164d306757fa353bf40446e2c87c4b.addTo(map_145cf48466f118fa12fcdd140b6ba329);
#
#
#             var marker_7a9a6dedb71014be1027945cca48c3ac = L.marker(
#                 [19.3229731, -98.2330294],
#                 {
# }
#             ).addTo(map_145cf48466f118fa12fcdd140b6ba329);
#
#
#             var icon_b12bfbe270d647b067ee20594662a23c = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;circle&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_5dd4ea4a9651fe25db803b50ea3c0109 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e53a091dc110e2b2874809560764aea4 = $(`&lt;div id=&quot;html_e53a091dc110e2b2874809560764aea4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Punto A&lt;/div&gt;`)[0];
#                 popup_5dd4ea4a9651fe25db803b50ea3c0109.setContent(html_e53a091dc110e2b2874809560764aea4);
#
#
#
#         marker_7a9a6dedb71014be1027945cca48c3ac.bindPopup(popup_5dd4ea4a9651fe25db803b50ea3c0109)
#         ;
#
#
#
#
#                 marker_7a9a6dedb71014be1027945cca48c3ac.setIcon(icon_b12bfbe270d647b067ee20594662a23c);
#
#
#             var marker_576ea2680cb00dfad7cb4b8116fa9f9b = L.marker(
#                 [19.2153912, -98.2408413],
#                 {
# }
#             ).addTo(map_145cf48466f118fa12fcdd140b6ba329);
#
#
#             var icon_155732d76c8f84c87df05992191ea430 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;circle&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_947ba271ce7d9ee8f6c4f8a39a2f4a11 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8a2c3955df4448c024b1f33b3d6fc416 = $(`&lt;div id=&quot;html_8a2c3955df4448c024b1f33b3d6fc416&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Punto B&lt;/div&gt;`)[0];
#                 popup_947ba271ce7d9ee8f6c4f8a39a2f4a11.setContent(html_8a2c3955df4448c024b1f33b3d6fc416);
#
#
#
#         marker_576ea2680cb00dfad7cb4b8116fa9f9b.bindPopup(popup_947ba271ce7d9ee8f6c4f8a39a2f4a11)
#         ;
#
#
#
#
#                 marker_576ea2680cb00dfad7cb4b8116fa9f9b.setIcon(icon_155732d76c8f84c87df05992191ea430);
#
#
#             var marker_85fd873312258a6d28e999bc33ef425f = L.marker(
#                 [19.3189998, -98.2209824],
#                 {
# }
#             ).addTo(map_145cf48466f118fa12fcdd140b6ba329);
#
#
#             var icon_e894544e08c6ce9b6e73c3ddd6567347 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;circle&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_59293e7065836e9cc638dd0d9b94c2d3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });

# %%
# ===================== GENERACIÓN DE MAPAS DE TRÁFICO =====================

def generar_mapas_trafico(metrics_rows, output_dir="Resultados/Mapas_Trafico"):
    """
    Genera un mapa HTML por cada par origen–destino, usando los segmentos de tráfico
    guardados en results["traffic_segments"].
    """
    os.makedirs(output_dir, exist_ok=True)

    for r in metrics_rows:
        segments = r.get("traffic_segments", [])
        if not segments:
            print(f"[INFO] Sin segmentos de tráfico para {r.get('origen')} -> {r.get('destino')}, se omite mapa.")
            continue

        # Centro del mapa: primer punto del primer segmento
        first_seg = segments[0]
        coords = first_seg.get("coords", [])
        if not coords:
            continue
        center_lat, center_lon = coords[0]

        origen = r.get("origen", "origen")
        destino = r.get("destino", "destino")

        # Limpiar nombres para archivo
        def slugify(name):
            return str(name).replace(" ", "_").replace("/", "-")

        filename = f"mapa_trafico_{slugify(origen)}_{slugify(destino)}.html"
        save_path = os.path.join(output_dir, filename)

        build_traffic_map_from_segments(
            segments,
            center_lat=center_lat,
            center_lon=center_lon,
            save_path=save_path
        )

        print(f"[OK] Mapa de tráfico guardado: {save_path}")


# Si en tu main ya tienes algo como:
# metrics_rows = evaluate_pairs_parallel(...)
# df_metrics = pd.DataFrame(metrics_rows)
# entonces aquí puedes hacer:
try:
    generar_mapas_trafico(metrics_rows)
except NameError:
    print("metrics_rows no está definido en este contexto. Asegúrate de llamarlo después de evaluate_pairs_parallel.")
